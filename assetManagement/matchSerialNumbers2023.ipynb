# %%
import pandas as pd
import numpy as np
import xarray as xr

# %%
# load in master RCA instrument list
master_df = pd.read_csv('./params/RCA-InstrumentList.csv')

# %%
master_df
# Out:
#                assetID instrumentType  mfgSN SNnotes
# 0    ATOSU-69825-00001        ADCPS-I  21498     NaN
# 1    ATOSU-69825-00002        ADCPS-I  18153     NaN
# 2    ATOSU-69825-00003        ADCPS-I  18919     NaN
# 3    ATAPL-58419-00001        ADCPS-K  18444     NaN
# 4    ATAPL-58419-00002        ADCPS-K  18975     NaN
# ..                 ...            ...    ...     ...
# 387  ATAPL-71444-00003     DP-VEHICLE      3     NaN
# 388  ATAPL-71444-00004     DP-VEHICLE      4     NaN
# 389  ATAPL-71444-00005     DP-VEHICLE      5     NaN
# 390  ATAPL-71444-00006     DP-VEHICLE      6     NaN
# 391  ATAPL-71444-00007     DP-VEHICLE      7     NaN
#
# [392 rows x 4 columns]

# %%
# load manual image overview CSV for the current year
imageSN_2021 = pd.read_csv('./params/imageSN_2021.csv')
imageSN_2023 = pd.read_csv('./params/imageSN_2023.csv')

# %%
imageSN_2021
# Out:
#             referenceDesignator  deployYear      imageFile imageSerialNumber  \
# 0   CE02SHBP-LJ01D-05-ADCPTB104        2020  IMG_4469.HEIC             19003
# 1   CE02SHBP-LJ01D-06-CTDBPN106        2020  IMG_4466.HEIC              7230
# 2   CE02SHBP-LJ01D-06-DOSTAD106        2020  IMG_4467.HEIC               216
# 3   CE02SHBP-LJ01D-07-VEL3DC108        2020  IMG_4468.HEIC         5007,8167
# 4   CE02SHBP-LJ01D-08-OPTAAD106        2020  IMG_4465.HEIC               169
# ..                          ...         ...            ...               ...
# 64  RS03AXPS-SF03A-3B-OPTAAD301        2020   IMG_1546.JPG               134
# 65  RS03AXPS-SF03A-3D-SPKIRA301        2020   IMG_1548.JPG               244
# 66  RS03AXPS-SF03A-4A-NUTNRA301        2020   IMG_1544.JPG               379
# 67  RS03AXPS-SF03A-4B-VELPTD302        2020   IMG_1544.JPG              6334
# 68  RS03AXPS-SF03A-4F-PCO2WA301        2020   IMG_1545.JPG             C0124
#
#          imageAssetID
# 0   ATOSU-69826-00002
# 1   ATOSU-69827-00001
# 2   ATOSU-58320-00020
# 3   ATOSU-69829-00003
# 4   ATOSU-58332-00009
# ..                ...
# 64  ATAPL-58332-00001
# 65  ATAPL-58341-00002
# 66  ATAPL-68020-00002
# 67  ATAPL-70114-00002
# 68  ATAPL-58336-00010
#
# [69 rows x 5 columns]

# %%
imageSN_2023.rename(columns={'ReferenceDesignator': 'referenceDesignator'}, inplace=True)

# %%
imageSN_2023
# Out:
#              referenceDesignator  deployYear  \
# 0    RS01SUM2-MJ01B-12-ADCPSK101        2018
# 1    RS01SLBS-LJ01A-10-ADCPTE101        2020
# 2    RS01SLBS-LJ01A-11-OPTAAC103        2020
# 3    RS01SLBS-LJ01A-12-CTDPFB101        2020
# 4    RS01SLBS-LJ01A-12-DOSTAD101        2020
# ..                           ...         ...
# 191  RS03INT1-MJ03C-05-CAMDSB303        2023
# 192  RS03INT1-MJ03C-07-PPSDNA301        2023
# 193  RS03INT1-MJ03C-07-RASFLA301        2023
# 194  RS03INT1-MJ03C-09-TRHPHA302        2023
# 195  RS03INT1-MJ03C-09-TRHPHA302        2023
#
#                                              imageFile imageSerialNumber  \
# 0    /Volumes/Data0/Archive/Cruise_data/RCA/Visions...             18977
# 1    /Volumes/Data0/Archive/Cruise_data/RCA/Visions...             18813
# 2    /Volumes/Data0/Archive/Cruise_data/RCA/Visions...               248
# 3    /Volumes/Data0/Archive/Cruise_data/RCA/Visions...        4830-67627
# 4    /Volumes/Data0/Archive/Cruise_data/RCA/Visions...               NaN
# ..                                                 ...               ...
# 191  /Volumes/Data0/Archive/Cruise_data/RCA/Visions...               301
# 192  /Volumes/Data0/Archive/Cruise_data/RCA/Visions...               NaN
# 193  /Volumes/Data0/Archive/Cruise_data/RCA/Visions...          12881-02
# 194  /Volumes/Data0/Archive/Cruise_data/RCA/Visions...                 2
# 195  /Volumes/Data0/Archive/Cruise_data/RCA/Visions...                 2
#
#           imageAssetID
# 0                  NaN
# 1                  NaN
# 2    ATAPL-69943-00008
# 3    ATAPL-67627-00002
# 4    ATAPL-58320-00014
# ..                 ...
# 191  ATAPL-70101-00022
# 192  ATAPL-58338-00001
# 193                NaN
# 194                NaN
# 195                NaN
#
# [196 rows x 5 columns]

# %%
imageSN = pd.concat([imageSN_2023, imageSN_2021], ignore_index=True)

# %%
imageSN
# Out:
#              referenceDesignator  deployYear  \
# 0    RS01SUM2-MJ01B-12-ADCPSK101        2018
# 1    RS01SLBS-LJ01A-10-ADCPTE101        2020
# 2    RS01SLBS-LJ01A-11-OPTAAC103        2020
# 3    RS01SLBS-LJ01A-12-CTDPFB101        2020
# 4    RS01SLBS-LJ01A-12-DOSTAD101        2020
# ..                           ...         ...
# 260  RS03AXPS-SF03A-3B-OPTAAD301        2020
# 261  RS03AXPS-SF03A-3D-SPKIRA301        2020
# 262  RS03AXPS-SF03A-4A-NUTNRA301        2020
# 263  RS03AXPS-SF03A-4B-VELPTD302        2020
# 264  RS03AXPS-SF03A-4F-PCO2WA301        2020
#
#                                              imageFile imageSerialNumber  \
# 0    /Volumes/Data0/Archive/Cruise_data/RCA/Visions...             18977
# 1    /Volumes/Data0/Archive/Cruise_data/RCA/Visions...             18813
# 2    /Volumes/Data0/Archive/Cruise_data/RCA/Visions...               248
# 3    /Volumes/Data0/Archive/Cruise_data/RCA/Visions...        4830-67627
# 4    /Volumes/Data0/Archive/Cruise_data/RCA/Visions...               NaN
# ..                                                 ...               ...
# 260                                       IMG_1546.JPG               134
# 261                                       IMG_1548.JPG               244
# 262                                       IMG_1544.JPG               379
# 263                                       IMG_1544.JPG              6334
# 264                                       IMG_1545.JPG             C0124
#
#           imageAssetID
# 0                  NaN
# 1                  NaN
# 2    ATAPL-69943-00008
# 3    ATAPL-67627-00002
# 4    ATAPL-58320-00014
# ..                 ...
# 260  ATAPL-58332-00001
# 261  ATAPL-58341-00002
# 262  ATAPL-68020-00002
# 263  ATAPL-70114-00002
# 264  ATAPL-58336-00010
#
# [265 rows x 5 columns]

# %%
def process_mfgSN(row):
    # some assests have multiple manufacturer serial numbers so we eplit them out
    mfgSN_values = row['mfgSN'].split(',')
    assetID = row['assetID']
    
    return {mfgSN_value: assetID for mfgSN_value in mfgSN_values}

# Applying the function along rows (axis=1)
mfg_dict = master_df.apply(process_mfgSN, axis=1).to_list()

# %%
# many dicts to one dict {'manufacturer_serialnumber' : 'assetID'} 
final_mfg_dict = {k: v for mfg_dict in mfg_dict for k, v in mfg_dict.items()}

# %%
# note that this has some repeated values because there are multiple serial numbers per assetID
final_mfg_dict
# Out:
# {'21498': 'ATOSU-69825-00001',
#  '18153': 'ATOSU-69825-00002',
#  '18919': 'ATOSU-69825-00003',
#  '18444': 'ATAPL-58419-00001',
#  '18975': 'ATAPL-58419-00002',
#  '18977': 'ATAPL-58419-00003',
#  '18493': 'ATOSU-69826-00001',
#  '19003': 'ATOSU-69826-00002',
#  '22115': 'ATOSU-69826-00003',
#  '18478': 'ATAPL-58315-00001',
#  '18974': 'ATAPL-58315-00002',
#  '18980': 'ATAPL-58315-00003',
#  '23338': 'ATAPL-58315-00004',
#  '23339': 'ATAPL-58315-00005',
#  '18471': 'ATAPL-68073-00001',
#  '18813': 'ATAPL-68073-00002',
#  '19224': 'ATAPL-68073-00003',
#  '23442': 'ATAPL-68073-00004',
#  '23443': 'ATAPL-68073-00005',
#  '1023': 'PIRSN-PADCPA-00001',
#  '3': 'ATAPL-71444-00003',
#  ' 9651': 'ATAPL-58316-00001',
#  ' 8643': 'ATAPL-58316-00001',
#  ' 120785': 'ATAPL-58316-00001',
#  '4': 'ATAPL-71444-00004',
#  ' 9655': 'ATAPL-58316-00002',
#  ' 3616': 'ATAPL-58316-00002',
#  ' 120788': 'ATAPL-58316-00002',
#  '5': 'ATAPL-71444-00005',
#  ' 9676': 'ATAPL-58316-00003',
#  ' 9914': 'ATAPL-58316-00003',
#  ' 120798': 'ATAPL-58316-00003',
#  '7': 'ATAPL-71444-00007',
#  ' 9652': 'ATAPL-58316-00004',
#  ' 3617': 'ATAPL-58316-00004',
#  ' 121184': 'ATAPL-58316-00004',
#  '8': 'ATAPL-58316-00005',
#  ' 9656': 'ATAPL-58316-00005',
#  ' 8642': 'ATAPL-58316-00005',
#  ' 121654': 'ATAPL-58316-00005',
#  'SUBC18830': 'ATAPL-78437-00001',
#  ' SUBC18825': 'ATAPL-78437-00001',
#  ' SUBC18826': 'ATAPL-78437-00001',
#  ' SUBC18901': 'ATAPL-78437-00001',
#  ' SUBC18907': 'ATAPL-78437-00001',
#  'SUBC18831': 'ATAPL-78437-00002',
#  ' SUBC18827': 'ATAPL-78437-00002',
#  ' SUBC18828': 'ATAPL-78437-00002',
#  ' SUBC18902': 'ATAPL-78437-00002',
#  ' SUBC18905': 'ATAPL-78437-00002',
#  'SUBC18832': 'ATAPL-78437-00003',
#  ' SUBC18829': 'ATAPL-78437-00003',
#  ' SUBC18836': 'ATAPL-78437-00003',
#  ' SUBC18903': 'ATAPL-78437-00003',
#  ' SUBC18904': 'ATAPL-78437-00003',
#  'SUBC18833': 'ATAPL-78437-00004',
#  ' SUBC18837': 'ATAPL-78437-00004',
#  ' SUBC18838': 'ATAPL-78437-00004',
#  ' SUBC18906': 'ATAPL-78437-00004',
#  ' SUBC18908': 'ATAPL-78437-00004',
#  'SUBC19005': 'ATAPL-78437-00005',
#  ' SUBC19974': 'ATAPL-78437-00005',
#  ' SUBC19976': 'ATAPL-78437-00005',
#  ' SUBC18918': 'ATAPL-78437-00005',
#  ' SUBC18915': 'ATAPL-78437-00005',
#  'SUBC19006': 'ATAPL-78437-00006',
#  ' SUBC19977': 'ATAPL-78437-00006',
#  ' SUBC19983': 'ATAPL-78437-00006',
#  ' SUBC18916': 'ATAPL-78437-00006',
#  ' SUBC18919': 'ATAPL-78437-00006',
#  'SUBC19007': 'ATAPL-78437-00007',
#  ' SUBC19034': 'ATAPL-78437-00007',
#  ' SUBC19035': 'ATAPL-78437-00007',
#  ' SUBC18926': 'ATAPL-78437-00007',
#  ' SUBC18930': 'ATAPL-78437-00007',
#  'SUBC19008': 'ATAPL-78437-00008',
#  ' SUBC19032': 'ATAPL-78437-00008',
#  ' SUBC19033': 'ATAPL-78437-00008',
#  ' SUBC18913': 'ATAPL-78437-00008',
#  ' SUBC18928': 'ATAPL-78437-00008',
#  'SUBC20116': 'ATAPL-78437-00009',
#  ' SUBC19048': 'ATAPL-78437-00009',
#  ' SUBC20140': 'ATAPL-78437-00009',
#  ' SUBC19014': 'ATAPL-78437-00009',
#  ' SUBC19022': 'ATAPL-78437-00009',
#  'SUBC20117': 'ATAPL-78437-00010',
#  ' SUBC20160': 'ATAPL-78437-00010',
#  ' SUBC20159': 'ATAPL-78437-00010',
#  ' SUBC19011': 'ATAPL-78437-00010',
#  ' SUBC19023': 'ATAPL-78437-00010',
#  'SUBC20118': 'ATAPL-78437-00011',
#  ' SUBC20158': 'ATAPL-78437-00011',
#  ' SUBC19980': 'ATAPL-78437-00011',
#  ' SUBC20100': 'ATAPL-78437-00011',
#  ' SUBC20103': 'ATAPL-78437-00011',
#  'SUBC20119': 'ATAPL-78437-00012',
#  ' SUBC20149': 'ATAPL-78437-00012',
#  ' SUBC20146': 'ATAPL-78437-00012',
#  ' SUBC20101': 'ATAPL-78437-00012',
#  ' SUBC20112': 'ATAPL-78437-00012',
#  'SUBC20120': 'ATAPL-78437-00013',
#  ' SUBC20161': 'ATAPL-78437-00013',
#  ' SUBC20145': 'ATAPL-78437-00013',
#  ' SUBC20105': 'ATAPL-78437-00013',
#  ' SUBC20115': 'ATAPL-78437-00013',
#  '101': 'ATAPL-58317-00001',
#  '102': 'ATAPL-58317-00002',
#  '103': 'ATAPL-58317-00003',
#  '104': 'ATAPL-58317-00004',
#  '107': 'ATAPL-58317-00005',
#  '108': 'ATAPL-58317-00006',
#  '114': 'ATAPL-58317-00009',
#  '115': 'ATAPL-58317-00010',
#  '116': 'ATAPL-58317-00011',
#  '100': 'ATOSU-58317-00007',
#  '105': 'ATOSU-58317-00008',
#  '117': 'ATOSU-58317-00012',
#  '118': 'ATOSU-58317-00013',
#  '13115': 'ATAPL-70248-00001',
#  ' 12108': 'ATAPL-70248-00001',
#  ' 12110': 'ATAPL-70248-00001',
#  ' 70502': 'ATAPL-70248-00001',
#  '13114': 'ATAPL-70248-00002',
#  ' 12099': 'ATAPL-70248-00002',
#  ' 12100': 'ATAPL-70248-00002',
#  ' 70501': 'ATAPL-70248-00002',
#  '1': 'ATAPL-71444-00001',
#  '16P71176-7230': 'ATOSU-69827-00001',
#  '16-50114': 'ATOSU-69827-00002',
#  '16P71879-7248': 'ATOSU-69827-00003',
#  '1401': 'ATAPL-78452-00003',
#  '1402': 'ATAPL-78452-00004',
#  '1403': 'ATAPL-78452-00005',
#  '1404': 'ATAPL-78452-00006',
#  '1405': 'ATAPL-78452-00007',
#  'C0047': 'ATAPL-58336-00001',
#  'C0075': 'ATAPL-58336-00002',
#  'C0076': 'ATAPL-58336-00003',
#  'C0091': 'ATAPL-58336-00004',
#  'C0123': 'ATAPL-58336-00009',
#  'C0124': 'ATAPL-58336-00010',
#  'C0078': 'ATOSU-58336-00005',
#  'C0079': 'ATOSU-58336-00006',
#  'C0116': 'ATOSU-58336-00007',
#  'C0117': 'ATOSU-58336-00008',
#  'C0064': 'ATOSU-70570-00001',
#  'C0080': 'ATOSU-70570-00002',
#  'C0090': 'ATOSU-70570-00003',
#  'C0118': 'ATOSU-70570-00004',
#  'P0059': 'ATAPL-58337-00001',
#  'P0112': 'ATAPL-58337-00002',
#  'P0111': 'ATAPL-58337-00003',
#  'P0110': 'ATAPL-58337-00004',
#  'P0113': 'ATAPL-58337-00005',
#  'P0133': 'ATAPL-58337-00006',
#  'P0161': 'ATAPL-58337-00009',
#  'P0162': 'ATAPL-58337-00010',
#  'P0163': 'ATAPL-58337-00013',
#  'P0164': 'ATAPL-58337-00014',
#  'P0115': 'ATOSU-58337-00007',
#  'P0131': 'ATOSU-58337-00008',
#  'P0153': 'ATOSU-58337-00011',
#  'P0154': 'ATOSU-58337-00012',
#  'P0116': 'ATOSU-70571-00001',
#  'P0117': 'ATOSU-70571-00002',
#  'P0132': 'ATOSU-70571-00003',
#  'P0159': 'ATOSU-70571-00004',
#  '12881-04': 'ATAPL-58338-00001',
#  '13003-01': 'ATAPL-58338-00002',
#  '12881-03': 'ATAPL-58338-00003',
#  '5463757-0012': 'ATAPL-67639-00001',
#  '5471540-0028': 'ATAPL-67639-00002',
#  '5471540-0029': 'ATAPL-67639-00003',
#  '5471540-0030': 'ATAPL-67639-00004',
#  '5471540-0046': 'ATAPL-67639-00005',
#  '5471540-0048': 'ATAPL-67639-00006',
#  '5471540-0031': 'ATAPL-69923-00001',
#  '5471540-0047': 'ATAPL-69923-00002',
#  '12881-01': 'ATAPL-58340-00001',
#  '12881-02': 'ATAPL-58340-00002',
#  '13003-02': 'ATAPL-58340-00003',
#  '233': 'ATAPL-58341-00001',
#  '245': 'ATAPL-58341-00003',
#  '267': 'ATAPL-58341-00004',
#  '292': 'ATAPL-58341-00006',
#  '293': 'ATAPL-58341-00007',
#  '241': 'ATOSU-58341-00005',
#  'C_oldA': 'ATAPL-58342-00001',
#  'B_oldC': 'ATAPL-58342-00002',
#  'A_oldB': 'ATAPL-58342-00003',
#  '21968': 'ATAPL-58343-00001',
#  '21969': 'ATAPL-58343-00002',
#  '21964': 'ATAPL-58343-00003',
#  ' 24494': 'ATAPL-58345-00001',
#  ' 61247': 'ATAPL-58345-00001',
#  '19073': 'ATAPL-58345-00002',
#  ' 64667': 'ATAPL-58345-00002',
#  '19075': 'ATAPL-58345-00003',
#  ' 64689': 'ATAPL-58345-00003',
#  '21829': 'ATAPL-58345-00004',
#  ' 23340': 'ATAPL-58345-00004',
#  '23248': 'ATAPL-58345-00005',
#  ' 23341': 'ATAPL-58345-00005',
#  '23244': 'ATAPL-58345-00006',
#  ' 23342': 'ATAPL-58345-00006',
#  '1001': 'ATAPL-58346-00001',
#  '1039': 'ATAPL-58346-00002',
#  '1148': 'ATAPL-58346-00004',
#  '1214': 'ATAPL-58346-00005',
#  '1215': 'ATAPL-58346-00006',
#  '1216': 'ATOSU-58346-00007',
#  '10306': 'ATAPL-67979-00001',
#  '10311': 'ATAPL-67979-00002',
#  '10312': 'ATAPL-67979-00003',
#  '10313': 'ATAPL-67979-00004',
#  '10314': 'ATAPL-67979-00005',
#  '10349': 'ATAPL-67979-00006',
#  '10350': 'ATAPL-67979-00007',
#  '10351': 'ATAPL-67979-00008',
#  '10352': 'ATAPL-67979-00009',
#  '10364': 'ATAPL-67979-00010',
#  'VEC-5157': 'ATOSU-69829-00001',
#  ' VEC-13934': 'ATOSU-69829-00001',
#  'VEC-5156': 'ATOSU-69829-00002',
#  ' VEC-12587': 'ATOSU-69829-00002',
#  'VEC-5007': 'ATOSU-69829-00003',
#  ' VEC-8167': 'ATOSU-69829-00003',
#  'VEC-4940': 'ATOSU-69829-00004',
#  ' VEC-8159': 'ATOSU-69829-00004',
#  'VEC-4943': 'ATOSU-69829-00005',
#  ' VEC-8181': 'ATOSU-69829-00005',
#  'AQS-6031': 'ATAPL-70114-00001',
#  ' AQD-8493': 'ATAPL-70114-00001',
#  'AQS-6334': 'ATAPL-70114-00002',
#  ' AQD-11653': 'ATAPL-70114-00002',
#  'AQS-6389': 'ATAPL-70114-00003',
#  ' AQD-11641': 'ATAPL-70114-00003',
#  'AQS-6802': 'ATAPL-70114-00004',
#  ' AQD-11930': 'ATAPL-70114-00004',
#  'AQS-7205': 'ATAPL-70114-00006',
#  ' AQD-12227': 'ATAPL-70114-00006',
#  'AQS-7340': 'ATAPL-70114-00007',
#  ' AQD-12469': 'ATAPL-70114-00007',
#  'AQS-5761': 'ATOSU-70114-10005',
#  ' AQD-8399': 'ATOSU-70114-10005',
#  'ALD-7050': 'ATOSU-70114-10008',
#  ' AQD-12692': 'ATOSU-70114-10008',
#  '6': 'ATAPL-71444-00006'}

# %%
def process_imageSN(row, mfg_dict):
    
    print('-----------------------------------------------')
    imageSerialNumbers = row['imageSerialNumber']
    imageAssetID = row['imageAssetID']
    
    if type(imageSerialNumbers) is str and '/' in imageSerialNumbers:
        imageSerialNumbers = row['imageSerialNumber'].split('/')
        print(f"it looks like there are multiple / SNs in this cell {imageSerialNumbers}")
    elif type(imageSerialNumbers) is str and ',' in imageSerialNumbers:
        imageSerialNumbers = row['imageSerialNumber'].split(',')
        print(f"it looks like there are multiple , SNs in this cell {imageSerialNumbers}")
    else:
        imageSerialNumbers = [imageSerialNumbers] # both list for consistency

    # list of matching asset ids
    match_list = []
    # proportion of serial number which matches if it is a partial match
    prop_list = []
    # list of the manufacturer serial numbers that match the imageSN
    mfg_sn_list = []

    # exact SN match
    exact_match_found = False 
    # assetID, exact SN or partial SN match
    any_match_found = False
    # exact assetID match
    exact_asset_match_found = False
    # any assetID match
    any_asset_match_found = False

    for imageSerialNumber in imageSerialNumbers:
        print(f"matching {imageSerialNumber}...")
        for manufacturerSerialNumber in mfg_dict.keys():
            if type(imageSerialNumber) is str and imageSerialNumber == manufacturerSerialNumber:
                print("exact match found")
                matching_assetID = mfg_dict[manufacturerSerialNumber]
                match_list.append(matching_assetID)
                mfg_sn_list.append(manufacturerSerialNumber)

                match_list = list(set(match_list))
    
                exact_match_found = True
                any_match_found = True
            
        if exact_match_found == False:
            for manufacturerSerialNumber in mfg_dict.keys():
                if type(imageSerialNumber) is str and imageSerialNumber in manufacturerSerialNumber and imageSerialNumber != manufacturerSerialNumber:
                    print("found a partial match")
                    matching_assetID = mfg_dict[manufacturerSerialNumber]
                    match_prop = round(len(imageSerialNumber) / len(manufacturerSerialNumber),2)
                    match_list.append(matching_assetID)
                    prop_list.append(match_prop)
                    mfg_sn_list.append(manufacturerSerialNumber)

                    match_list = list(set(match_list))
    
                    any_match_found = True

        if any_match_found == False:
            print(f"still no match - attempting to match by assetID <{imageAssetID}> instead...")
            for master_assetID in mfg_dict.values():
                if type(imageAssetID) is str and imageAssetID == master_assetID:
                    print("exact assetID match found")
                    matching_assetID = master_assetID
                    match_list.append(matching_assetID)

                    match_list = list(set(match_list))
    
                    any_match_found = True
                    exact_asset_match_found = True
                
            
    if len(match_list) > 0:
        row['matching_asset_ids'] = match_list
    else: 
        row['matching_asset_ids'] = np.nan

    if len(prop_list) > 0: 
        row['proportion_match'] = prop_list
    else: 
        row['proportion_match'] = np.nan

    if len(mfg_sn_list) > 0:
        row['matching_mfg_sn'] = mfg_sn_list
    else:
        row['matching_mfg_sn'] = np.nan

    if exact_match_found == False:
        row["exact_SN_match"] = np.nan
    else:
        row["exact_SN_match"] = True

    if exact_asset_match_found == False:
        row["exact_assetID_match"] = np.nan
    else:
        row["exact_assetID_match"] = True

    if any_match_found == False:
        row["any_match"] = np.nan
    else:
        row["any_match"] = True

    return row

# %%
imageSN = imageSN.apply(process_imageSN, axis=1, args=(final_mfg_dict,))
# Out:
# -----------------------------------------------
# matching 18977...
# exact match found
# -----------------------------------------------
# matching 18813...
# exact match found
# -----------------------------------------------
# matching 248...
# exact match found
# -----------------------------------------------
# matching 4830-67627...
# still no match - attempting to match by assetID <ATAPL-67627-00002> instead...
# exact assetID match found
# -----------------------------------------------
# matching nan...
# still no match - attempting to match by assetID <ATAPL-58320-00014> instead...
# exact assetID match found
# -----------------------------------------------
# matching nan...
# still no match - attempting to match by assetID <ATAPL-70150-00006> instead...
# -----------------------------------------------
# matching nan...
# still no match - attempting to match by assetID <ATAPL-70101-00003> instead...
# -----------------------------------------------
# matching 19003...
# exact match found
# -----------------------------------------------
# matching -7248...
# found a partial match
# -----------------------------------------------
# matching 216...
# exact match found
# -----------------------------------------------
# it looks like there are multiple / SNs in this cell ['5007', '8167']
# matching 5007...
# found a partial match
# matching 8167...
# found a partial match
# -----------------------------------------------
# matching 169...
# exact match found
# -----------------------------------------------
# matching C0080...
# exact match found
# -----------------------------------------------
# matching P0116...
# exact match found
# -----------------------------------------------
# matching 1248...
# exact match found
# -----------------------------------------------
# matching 1233...
# still no match - attempting to match by assetID <nan> instead...
# -----------------------------------------------
# matching 21498...
# exact match found
# -----------------------------------------------
# matching -7231...
# found a partial match
# -----------------------------------------------
# matching 133...
# exact match found
# -----------------------------------------------
# it looks like there are multiple / SNs in this cell ['4940', '8159']
# matching 4940...
# found a partial match
# matching 8159...
# found a partial match
# -----------------------------------------------
# matching 191...
# exact match found
# -----------------------------------------------
# matching C0064...
# exact match found
# -----------------------------------------------
# matching P0117...
# exact match found
# -----------------------------------------------
# matching 1248...
# exact match found
# -----------------------------------------------
# matching nan...
# still no match - attempting to match by assetID <ATAPL-78437-0013A> instead...
# -----------------------------------------------
# matching 52-0139...
# exact match found
# -----------------------------------------------
# matching 1148...
# exact match found
# -----------------------------------------------
# matching 3400...
# exact match found
# -----------------------------------------------
# matching 459...
# exact match found
# -----------------------------------------------
# matching 16-50018...
# exact match found
# -----------------------------------------------
# matching P0115...
# exact match found
# -----------------------------------------------
# matching C0079...
# exact match found
# -----------------------------------------------
# matching nan...
# still no match - attempting to match by assetID <ATAPL-66662-00005> instead...
# exact assetID match found
# -----------------------------------------------
# matching nan...
# still no match - attempting to match by assetID <ATAPL-58694-00003> instead...
# exact assetID match found
# -----------------------------------------------
# matching P0133...
# exact match found
# -----------------------------------------------
# matching 1292...
# exact match found
# -----------------------------------------------
# matching 186...
# exact match found
# -----------------------------------------------
# matching 617...
# exact match found
# -----------------------------------------------
# it looks like there are multiple / SNs in this cell ['7205', '12227']
# matching 7205...
# found a partial match
# found a partial match
# matching 12227...
# found a partial match
# -----------------------------------------------
# matching C0117...
# exact match found
# -----------------------------------------------
# matching 52-0145...
# exact match found
# -----------------------------------------------
# matching 52-0139...
# exact match found
# -----------------------------------------------
# matching 3460...
# exact match found
# -----------------------------------------------
# matching 3468...
# exact match found
# -----------------------------------------------
# matching 137...
# exact match found
# -----------------------------------------------
# matching 23339...
# exact match found
# -----------------------------------------------
# matching 19073...
# exact match found
# -----------------------------------------------
# matching nan...
# still no match - attempting to match by assetID <ATAPL-78438-00006> instead...
# -----------------------------------------------
# matching 1361...
# exact match found
# -----------------------------------------------
# matching 16P65795-6914...
# exact match found
# -----------------------------------------------
# matching P0164...
# exact match found
# -----------------------------------------------
# matching 1132...
# exact match found
# -----------------------------------------------
# matching -7205...
# found a partial match
# found a partial match
# -----------------------------------------------
# matching P0163...
# exact match found
# -----------------------------------------------
# matching 1130...
# exact match found
# -----------------------------------------------
# matching 244...
# exact match found
# -----------------------------------------------
# matching 380...
# exact match found
# -----------------------------------------------
# matching 6389...
# found a partial match
# -----------------------------------------------
# matching C0091...
# exact match found
# -----------------------------------------------
# matching nan...
# still no match - attempting to match by assetID <ATAPL-58344-00004> instead...
# -----------------------------------------------
# matching 3...
# exact match found
# -----------------------------------------------
# matching 1...
# exact match found
# -----------------------------------------------
# matching nan...
# still no match - attempting to match by assetID <ATOSU-70101-00013> instead...
# -----------------------------------------------
# matching 2...
# exact match found
# -----------------------------------------------
# matching 308...
# found a partial match
# -----------------------------------------------
# matching 156...
# exact match found
# -----------------------------------------------
# matching -50031...
# found a partial match
# -----------------------------------------------
# matching 273...
# exact match found
# -----------------------------------------------
# matching 52-0144...
# exact match found
# -----------------------------------------------
# matching 1214...
# exact match found
# -----------------------------------------------
# matching 3099...
# exact match found
# -----------------------------------------------
# matching 3098...
# exact match found
# -----------------------------------------------
# matching 458...
# exact match found
# -----------------------------------------------
# matching 18980...
# exact match found
# -----------------------------------------------
# matching 19075...
# exact match found
# -----------------------------------------------
# matching nan...
# still no match - attempting to match by assetID <ATAPL-78438-00001> instead...
# -----------------------------------------------
# matching 1272...
# exact match found
# -----------------------------------------------
# matching 16P71179-7233...
# exact match found
# -----------------------------------------------
# matching 1794559...
# still no match - attempting to match by assetID <nan> instead...
# -----------------------------------------------
# matching P0110...
# exact match found
# -----------------------------------------------
# matching 1131...
# exact match found
# -----------------------------------------------
# matching 90641-102...
# still no match - attempting to match by assetID <nan> instead...
# -----------------------------------------------
# matching 1794924...
# still no match - attempting to match by assetID <nan> instead...
# -----------------------------------------------
# matching P0112...
# exact match found
# -----------------------------------------------
# matching 5967...
# exact match found
# -----------------------------------------------
# matching 134...
# exact match found
# -----------------------------------------------
# matching 379...
# exact match found
# -----------------------------------------------
# matching 6334...
# found a partial match
# -----------------------------------------------
# matching C0124...
# exact match found
# -----------------------------------------------
# matching 2595170...
# still no match - attempting to match by assetID <nan> instead...
# -----------------------------------------------
# matching 16-50321...
# exact match found
# -----------------------------------------------
# matching TABGB1052295...
# still no match - attempting to match by assetID <ATAPL-58340-00002> instead...
# exact assetID match found
# -----------------------------------------------
# matching nan...
# still no match - attempting to match by assetID <ATAPL-58338-00003> instead...
# exact assetID match found
# -----------------------------------------------
# matching TABGB1052295...
# still no match - attempting to match by assetID <ATAPL-58340-00002> instead...
# exact assetID match found
# -----------------------------------------------
# matching 18493...
# exact match found
# -----------------------------------------------
# matching 16-50114...
# exact match found
# -----------------------------------------------
# matching 311...
# exact match found
# -----------------------------------------------
# matching 13934...
# found a partial match
# -----------------------------------------------
# matching 221...
# exact match found
# -----------------------------------------------
# matching C0116...
# exact match found
# -----------------------------------------------
# matching P0131...
# exact match found
# -----------------------------------------------
# matching 141...
# exact match found
# -----------------------------------------------
# matching 2...
# exact match found
# -----------------------------------------------
# matching 18153...
# exact match found
# -----------------------------------------------
# matching 7249...
# found a partial match
# -----------------------------------------------
# matching 381...
# exact match found
# -----------------------------------------------
# it looks like there are multiple / SNs in this cell ['5156', '12587']
# matching 5156...
# found a partial match
# matching 12587...
# found a partial match
# -----------------------------------------------
# matching 140...
# exact match found
# -----------------------------------------------
# matching C0090...
# exact match found
# -----------------------------------------------
# matching P0132...
# exact match found
# -----------------------------------------------
# matching 1250...
# exact match found
# -----------------------------------------------
# matching nan...
# still no match - attempting to match by assetID <ATAPL-78437-00058> instead...
# -----------------------------------------------
# matching 52-0146...
# exact match found
# -----------------------------------------------
# matching nan...
# still no match - attempting to match by assetID <ATAPL-58346-00002> instead...
# exact assetID match found
# -----------------------------------------------
# matching 3399...
# exact match found
# -----------------------------------------------
# matching 3762...
# exact match found
# -----------------------------------------------
# matching 125...
# exact match found
# -----------------------------------------------
# matching 171...
# still no match - attempting to match by assetID <ATAPL-78516-20001> instead...
# -----------------------------------------------
# matching 16-50113...
# exact match found
# -----------------------------------------------
# matching 316...
# exact match found
# -----------------------------------------------
# matching P0162...
# exact match found
# -----------------------------------------------
# matching C0123...
# exact match found
# -----------------------------------------------
# matching 50019...
# found a partial match
# -----------------------------------------------
# matching 43-2853...
# exact match found
# -----------------------------------------------
# matching P0153...
# exact match found
# -----------------------------------------------
# matching 1289...
# exact match found
# -----------------------------------------------
# matching 166...
# exact match found
# -----------------------------------------------
# matching 625...
# exact match found
# -----------------------------------------------
# matching AQD-12692...
# found a partial match
# -----------------------------------------------
# matching C0078...
# exact match found
# -----------------------------------------------
# matching nan...
# still no match - attempting to match by assetID <ATAPL-67977-00007> instead...
# -----------------------------------------------
# matching 3717...
# exact match found
# -----------------------------------------------
# matching 3397...
# exact match found
# -----------------------------------------------
# matching 317...
# exact match found
# -----------------------------------------------
# matching 23338...
# exact match found
# -----------------------------------------------
# it looks like there are multiple / SNs in this cell ['21829', '23340']
# matching 21829...
# exact match found
# matching 23340...
# -----------------------------------------------
# matching 18838...
# found a partial match
# -----------------------------------------------
# matching 1292...
# exact match found
# -----------------------------------------------
# matching 16-50118...
# exact match found
# -----------------------------------------------
# matching 472...
# exact match found
# -----------------------------------------------
# matching P0111...
# exact match found
# -----------------------------------------------
# matching 1129...
# exact match found
# -----------------------------------------------
# matching 16-50115...
# exact match found
# -----------------------------------------------
# matching 43-3163...
# exact match found
# -----------------------------------------------
# matching P0113...
# exact match found
# -----------------------------------------------
# matching 1150...
# exact match found
# -----------------------------------------------
# matching 223...
# exact match found
# -----------------------------------------------
# matching 334...
# found a partial match
# found a partial match
# found a partial match
# found a partial match
# -----------------------------------------------
# matching 6802...
# found a partial match
# -----------------------------------------------
# matching C0076...
# exact match found
# -----------------------------------------------
# matching ATAPL-50324-00011...
# still no match - attempting to match by assetID <nan> instead...
# -----------------------------------------------
# matching 18813...
# exact match found
# -----------------------------------------------
# matching 05-08317...
# still no match - attempting to match by assetID <nan> instead...
# -----------------------------------------------
# matching ATAPL-67627-00004...
# still no match - attempting to match by assetID <nan> instead...
# -----------------------------------------------
# matching ATAPL-58320-00014...
# still no match - attempting to match by assetID <nan> instead...
# -----------------------------------------------
# matching 1...
# exact match found
# -----------------------------------------------
# matching 2...
# exact match found
# -----------------------------------------------
# matching 3...
# exact match found
# -----------------------------------------------
# matching SUBC-19007...
# still no match - attempting to match by assetID <ATAPL-78437-00007> instead...
# exact assetID match found
# exact assetID match found
# exact assetID match found
# exact assetID match found
# exact assetID match found
# -----------------------------------------------
# matching 18975...
# exact match found
# -----------------------------------------------
# matching 4...
# exact match found
# -----------------------------------------------
# matching 16-50209...
# exact match found
# -----------------------------------------------
# matching 4813-64769...
# still no match - attempting to match by assetID <ATAPL-64769-00050> instead...
# -----------------------------------------------
# matching 307...
# found a partial match
# -----------------------------------------------
# matching nan...
# still no match - attempting to match by assetID <ATAPL-69943-00009> instead...
# exact assetID match found
# -----------------------------------------------
# matching nan...
# still no match - attempting to match by assetID <ATAPL-67627-00005> instead...
# exact assetID match found
# -----------------------------------------------
# matching nan...
# still no match - attempting to match by assetID <ATAPL-58320-00006> instead...
# exact assetID match found
# -----------------------------------------------
# matching 52-0137...
# exact match found
# -----------------------------------------------
# matching 1130...
# exact match found
# -----------------------------------------------
# matching 3716...
# exact match found
# -----------------------------------------------
# matching 3637...
# exact match found
# -----------------------------------------------
# matching nan...
# still no match - attempting to match by assetID <ATAPL-58320-00004> instead...
# exact assetID match found
# -----------------------------------------------
# matching 18974...
# exact match found
# -----------------------------------------------
# matching 61247...
# found a partial match
# -----------------------------------------------
# it looks like there are multiple / SNs in this cell ['18915', '18918']
# matching 18915...
# found a partial match
# matching 18918...
# found a partial match
# -----------------------------------------------
# matching 1362...
# exact match found
# -----------------------------------------------
# matching 16-50123...
# exact match found
# -----------------------------------------------
# matching 473...
# exact match found
# -----------------------------------------------
# matching P0059...
# exact match found
# -----------------------------------------------
# matching 1294...
# exact match found
# -----------------------------------------------
# matching 16-50122...
# exact match found
# -----------------------------------------------
# matching P0161...
# exact match found
# -----------------------------------------------
# matching 1293...
# exact match found
# -----------------------------------------------
# matching 251...
# exact match found
# -----------------------------------------------
# matching 1402...
# exact match found
# -----------------------------------------------
# matching 293...
# exact match found
# -----------------------------------------------
# matching NTR-0618...
# still no match - attempting to match by assetID <nan> instead...
# -----------------------------------------------
# matching AQD-12469...
# found a partial match
# -----------------------------------------------
# matching C0075...
# exact match found
# -----------------------------------------------
# matching 16-50327...
# exact match found
# -----------------------------------------------
# matching 16-50326...
# exact match found
# -----------------------------------------------
# matching 301...
# still no match - attempting to match by assetID <ATAPL-70101-00022> instead...
# -----------------------------------------------
# matching nan...
# still no match - attempting to match by assetID <ATAPL-58338-00001> instead...
# exact assetID match found
# -----------------------------------------------
# matching 12881-02...
# exact match found
# -----------------------------------------------
# matching 2...
# exact match found
# -----------------------------------------------
# matching 2...
# exact match found
# -----------------------------------------------
# matching 19003...
# exact match found
# -----------------------------------------------
# matching 7230...
# found a partial match
# -----------------------------------------------
# matching 216...
# exact match found
# -----------------------------------------------
# it looks like there are multiple , SNs in this cell ['5007', '8167']
# matching 5007...
# found a partial match
# matching 8167...
# found a partial match
# -----------------------------------------------
# matching 169...
# exact match found
# -----------------------------------------------
# matching C0080...
# exact match found
# -----------------------------------------------
# matching P0116...
# exact match found
# -----------------------------------------------
# matching 21498...
# exact match found
# -----------------------------------------------
# matching 7231...
# found a partial match
# -----------------------------------------------
# matching 133...
# exact match found
# -----------------------------------------------
# it looks like there are multiple , SNs in this cell ['VEC-4940', '8159']
# matching VEC-4940...
# exact match found
# matching 8159...
# -----------------------------------------------
# matching 191...
# exact match found
# -----------------------------------------------
# matching C0064...
# exact match found
# -----------------------------------------------
# matching P0117...
# exact match found
# -----------------------------------------------
# matching 52-0145...
# exact match found
# -----------------------------------------------
# matching 1131...
# exact match found
# -----------------------------------------------
# matching 3400...
# exact match found
# -----------------------------------------------
# matching 3398...
# exact match found
# -----------------------------------------------
# matching 137...
# exact match found
# -----------------------------------------------
# matching 2...
# exact match found
# -----------------------------------------------
# matching 50018...
# found a partial match
# -----------------------------------------------
# matching 215...
# exact match found
# -----------------------------------------------
# matching P0115...
# exact match found
# -----------------------------------------------
# matching C0079...
# exact match found
# -----------------------------------------------
# matching 50019...
# found a partial match
# -----------------------------------------------
# matching P0131...
# exact match found
# -----------------------------------------------
# matching 1150...
# exact match found
# -----------------------------------------------
# matching 128...
# exact match found
# -----------------------------------------------
# matching 267...
# exact match found
# -----------------------------------------------
# matching 344...
# exact match found
# -----------------------------------------------
# matching C0116...
# exact match found
# -----------------------------------------------
# matching 52-0120...
# exact match found
# -----------------------------------------------
# matching 1214...
# exact match found
# -----------------------------------------------
# matching 3098...
# exact match found
# -----------------------------------------------
# matching 3099...
# exact match found
# -----------------------------------------------
# matching 458...
# exact match found
# -----------------------------------------------
# matching 18478...
# exact match found
# -----------------------------------------------
# matching 19075...
# exact match found
# -----------------------------------------------
# matching 6914...
# found a partial match
# -----------------------------------------------
# matching 275...
# exact match found
# -----------------------------------------------
# matching P0164...
# exact match found
# -----------------------------------------------
# matching 1132...
# exact match found
# -----------------------------------------------
# matching 7205...
# found a partial match
# found a partial match
# -----------------------------------------------
# matching P0163...
# exact match found
# -----------------------------------------------
# matching 1130...
# exact match found
# -----------------------------------------------
# matching 244...
# exact match found
# -----------------------------------------------
# matching 1399...
# exact match found
# -----------------------------------------------
# matching 245...
# exact match found
# -----------------------------------------------
# matching 380...
# exact match found
# -----------------------------------------------
# matching 6389...
# found a partial match
# -----------------------------------------------
# matching C0091...
# exact match found
# -----------------------------------------------
# matching 52-0144...
# exact match found
# -----------------------------------------------
# matching 1148...
# exact match found
# -----------------------------------------------
# matching 3460...
# exact match found
# -----------------------------------------------
# matching 3468...
# exact match found
# -----------------------------------------------
# matching 459...
# exact match found
# -----------------------------------------------
# matching 19073...
# exact match found
# -----------------------------------------------
# matching 7233...
# found a partial match
# -----------------------------------------------
# matching 344...
# exact match found
# -----------------------------------------------
# matching P0113...
# exact match found
# -----------------------------------------------
# matching 1131...
# exact match found
# -----------------------------------------------
# matching 7232...
# found a partial match
# -----------------------------------------------
# matching P0112...
# exact match found
# -----------------------------------------------
# matching 5967...
# exact match found
# -----------------------------------------------
# matching 134...
# exact match found
# -----------------------------------------------
# matching 244...
# exact match found
# -----------------------------------------------
# matching 379...
# exact match found
# -----------------------------------------------
# matching 6334...
# found a partial match
# -----------------------------------------------
# matching C0124...
# exact match found

# %%
imageSN
# Out:
#              referenceDesignator  deployYear  \
# 0    RS01SUM2-MJ01B-12-ADCPSK101        2018
# 1    RS01SLBS-LJ01A-10-ADCPTE101        2020
# 2    RS01SLBS-LJ01A-11-OPTAAC103        2020
# 3    RS01SLBS-LJ01A-12-CTDPFB101        2020
# 4    RS01SLBS-LJ01A-12-DOSTAD101        2020
# ..                           ...         ...
# 260  RS03AXPS-SF03A-3B-OPTAAD301        2020
# 261  RS03AXPS-SF03A-3D-SPKIRA301        2020
# 262  RS03AXPS-SF03A-4A-NUTNRA301        2020
# 263  RS03AXPS-SF03A-4B-VELPTD302        2020
# 264  RS03AXPS-SF03A-4F-PCO2WA301        2020
#
#                                              imageFile imageSerialNumber  \
# 0    /Volumes/Data0/Archive/Cruise_data/RCA/Visions...             18977
# 1    /Volumes/Data0/Archive/Cruise_data/RCA/Visions...             18813
# 2    /Volumes/Data0/Archive/Cruise_data/RCA/Visions...               248
# 3    /Volumes/Data0/Archive/Cruise_data/RCA/Visions...        4830-67627
# 4    /Volumes/Data0/Archive/Cruise_data/RCA/Visions...               NaN
# ..                                                 ...               ...
# 260                                       IMG_1546.JPG               134
# 261                                       IMG_1548.JPG               244
# 262                                       IMG_1544.JPG               379
# 263                                       IMG_1544.JPG              6334
# 264                                       IMG_1545.JPG             C0124
#
#           imageAssetID   matching_asset_ids proportion_match matching_mfg_sn  \
# 0                  NaN  [ATAPL-58419-00003]              NaN         [18977]
# 1                  NaN  [ATAPL-68073-00002]              NaN         [18813]
# 2    ATAPL-69943-00008  [ATAPL-69943-00008]              NaN           [248]
# 3    ATAPL-67627-00002  [ATAPL-67627-00002]              NaN             NaN
# 4    ATAPL-58320-00014  [ATAPL-58320-00014]              NaN             NaN
# ..                 ...                  ...              ...             ...
# 260  ATAPL-58332-00001  [ATAPL-58332-00001]              NaN           [134]
# 261  ATAPL-58341-00002  [ATAPL-58341-00002]              NaN           [244]
# 262  ATAPL-68020-00002  [ATAPL-68020-00002]              NaN           [379]
# 263  ATAPL-70114-00002  [ATAPL-70114-00002]            [0.5]      [AQS-6334]
# 264  ATAPL-58336-00010  [ATAPL-58336-00010]              NaN         [C0124]
#
#     exact_SN_match exact_assetID_match any_match
# 0             True                 NaN      True
# 1             True                 NaN      True
# 2             True                 NaN      True
# 3              NaN                True      True
# 4              NaN                True      True
# ..             ...                 ...       ...
# 260           True                 NaN      True
# 261           True                 NaN      True
# 262           True                 NaN      True
# 263            NaN                 NaN      True
# 264           True                 NaN      True
#
# [265 rows x 11 columns]

# %%
imageSN.to_csv("./reportOuts/matchedSerialNumbers_2023.csv")
